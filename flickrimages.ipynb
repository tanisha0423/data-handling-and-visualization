# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/BL-Flickr-Images-Book (1).csv")
print(df.head())
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# 3  Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 4  [The World in which I live, and my place in it...  A., E. S.
#
#                                    Contributors  Corporate Author  \
# 0                               FORBES, Walter.               NaN
# 1  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3                   Appleyard, Ernest Silvanus.               NaN
# 4                           BROOME, John Henry.               NaN
#
#    Corporate Contributors Former owner  Engraver Issuance type  \
# 0                     NaN          NaN       NaN   monographic
# 1                     NaN          NaN       NaN   monographic
# 2                     NaN          NaN       NaN   monographic
# 3                     NaN          NaN       NaN   monographic
# 4                     NaN          NaN       NaN   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.

# %%
to_drop=["Edition Statement"]

# %%
df.drop(to_drop,inplace=True,axis=1)

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors  Corporate Author  \
# 0      A. A.                               FORBES, Walter.               NaN
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 3  A., E. S.                   Appleyard, Ernest Silvanus.               NaN
# 4  A., E. S.                           BROOME, John Henry.               NaN
#
#    Corporate Contributors Former owner  Engraver Issuance type  \
# 0                     NaN          NaN       NaN   monographic
# 1                     NaN          NaN       NaN   monographic
# 2                     NaN          NaN       NaN   monographic
# 3                     NaN          NaN       NaN   monographic
# 4                     NaN          NaN       NaN   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.

# %%
for col in df.columns:
  print(col)
# Out:
# Identifier
# Place of Publication
# Date of Publication
# Publisher
# Title
# Author
# Contributors
# Corporate Author
# Corporate Contributors
# Former owner
# Engraver
# Issuance type
# Flickr URL
# Shelfmarks

# %%
df.set_index('Identifier',inplace=True)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
#
#                                                         Title     Author  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A      A. A.
# 216         All for Greed. [A novel. The dedication signed...  A., A. A.
# 218         Love the Avenger. By the author of “All for Gr...  A., A. A.
# 472         Welsh Sketches, chiefly ecclesiastical, to the...  A., E. S.
# 480         [The World in which I live, and my place in it...  A., E. S.
#
#                                             Contributors  Corporate Author  \
# Identifier
# 206                                      FORBES, Walter.               NaN
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 218         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 472                          Appleyard, Ernest Silvanus.               NaN
# 480                                  BROOME, John Henry.               NaN
#
#             Corporate Contributors Former owner  Engraver Issuance type  \
# Identifier
# 206                            NaN          NaN       NaN   monographic
# 216                            NaN          NaN       NaN   monographic
# 218                            NaN          NaN       NaN   monographic
# 472                            NaN          NaN       NaN   monographic
# 480                            NaN          NaN       NaN   monographic
#
#                                                    Flickr URL  \
# Identifier
# 206         http://www.flickr.com/photos/britishlibrary/ta...
# 216         http://www.flickr.com/photos/britishlibrary/ta...
# 218         http://www.flickr.com/photos/britishlibrary/ta...
# 472         http://www.flickr.com/photos/britishlibrary/ta...
# 480         http://www.flickr.com/photos/britishlibrary/ta...
#
#                                      Shelfmarks
# Identifier
# 206           British Library HMNTS 12641.b.30.
# 216           British Library HMNTS 12626.cc.2.
# 218           British Library HMNTS 12625.dd.1.
# 472         British Library HMNTS 10369.bbb.15.
# 480            British Library HMNTS 9007.d.28.

# %%
unwanted_characters=['[',',','-']
def clean_dates(item):
  dop=str(item.loc['Date of Publication'])
  if dop=='nan'or dop[0] =='[':
    return np.NaN
  for character in unwanted_characters:
    if character in dop:
      character_index=dop.find(character)
      dop=dop[:character_index]
  return dop
df['Date of Publication']=df.apply(clean_dates,axis=1)

# %%
df.head(25)
# Out:
#                            Place of Publication Date of Publication  \
# Identifier
# 206                                      London               1879
# 216                    London; Virtue & Yorston                1868
# 218                                      London                1869
# 472                                      London                1851
# 480                                      London                1857
# 481                                      London                1875
# 519                                      London                1872
# 667         pp. 40. G. Bryan & Co: Oxford, 1898                 NaN
# 874                                     London]                1676
# 1143                                     London                1679
# 1280                                   Coventry                1802
# 1808                                Christiania                1859
# 1905                                    Firenze                1888
# 1929                                  Amsterdam                1839
# 2836                                     Savona                1897
# 2854                                     London                1865
# 2956                                      Paris                1860
# 2957                                      Paris                1873
# 3017                                Puerto-Rico                1866
# 3131                                   New York                1899
# 4598                                       Hull                1814
# 4884                                     London                1820
# 4976                                     Oxonii                1800
# 5382                                     London                1847
# 5385                                     London                 NaN
#
#                         Publisher  \
# Identifier
# 206              S. Tinsley & Co.
# 216                  Virtue & Co.
# 218         Bradbury, Evans & Co.
# 472                 James Darling
# 480          Wertheim & Macintosh
# 481             William Macintosh
# 519                    The Author
# 667                           NaN
# 874                           NaN
# 1143                          NaN
# 1280         Printed by J. Turner
# 1808                          NaN
# 1905                          NaN
# 1929                          NaN
# 2836                          NaN
# 2854               E. Moxon & Co.
# 2956                          NaN
# 2957                          NaN
# 3017                          NaN
# 3131                    W. Abbatt
# 4598                   The Author
# 4884            J. Hatchard & Son
# 4976               J. Cooke, etc.
# 5382                 Punch Office
# 5385        Bradbury, Agnew & Co.
#
#                                                         Title  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A
# 216         All for Greed. [A novel. The dedication signed...
# 218         Love the Avenger. By the author of “All for Gr...
# 472         Welsh Sketches, chiefly ecclesiastical, to the...
# 480         [The World in which I live, and my place in it...
# 481         [The World in which I live, and my place in it...
# 519         Lagonells. By the author of Darmayne (F. E. A....
# 667         The Coming of Spring, and other poems. By J. A...
# 874         A Warning to the inhabitants of England, and L...
# 1143        A Satyr against Vertue. (A poem: supposed to b...
# 1280        An Account of the many and great Loans, Benefa...
# 1808        Erindringer som Bidrag til Norges Historie fra...
# 1905        Gli Studi storici in terra d'Otranto ... Framm...
# 1929        De Aardbol. Magazijn van hedendaagsche land- e...
# 2836        Cronache Savonesi dal 1500 al 1570 ... Accresc...
# 2854        See-Saw; a novel ... Edited [or rather, writte...
# 2956        Géodésie d'une partie de la Haute Éthiopie,...
# 2957                                      [With eleven maps.]
# 3017        [Historia geográfica, civil y politica de la ...
# 3131        The Crisis of the Revolution, being the story ...
# 4598        Peace: a lyric poem. [With prefatory address b...
# 4884        Abdallah; or, The Arabian Martyr: a Christian ...
# 4976        [Abdollatiphi Historiæ Ægypti compendium. [Wit...
# 5382        The Comic History of England ... With ... colo...
# 5385        [The comic history of England ... With twenty ...
#
#                                                        Author  \
# Identifier
# 206                                                     A. A.
# 216                                                 A., A. A.
# 218                                                 A., A. A.
# 472                                                 A., E. S.
# 480                                                 A., E. S.
# 481                                                 A., E. S.
# 519                                                 A., F. E.
# 667                                             A., J.|A., J.
# 874                                                    Remaʿ.
# 1143                                                   A., T.
# 1280                                                      NaN
# 1808                                             AALL, Jacob.
# 1905        AAR, Ermanno - pseud. [i.e. Luigi Giuseppe Oro...
# 1929                                                      NaN
# 2836                                ABATE, Giovanni Agostino.
# 2854                                        ABATI, Francesco.
# 2956                            ABBADIE, Antoine Thompson d'.
# 2957                            ABBADIE, Antoine Thompson d'.
# 3017        ABBAD Y LASIERRA, Agustín Íñigo - Bishop of...
# 3131                                         ABBATT, William.
# 4598                                   ABBOTT, Thomas Eastoe.
# 4884                                                      NaN
# 4976                                                      NaN
# 5382                               A'BECKETT, Gilbert Abbott.
# 5385                               A'BECKETT, Gilbert Abbott.
#
#                                                  Contributors  \
# Identifier
# 206                                           FORBES, Walter.
# 216              BLAZE DE BURY, Marie Pauline Rose - Baroness
# 218              BLAZE DE BURY, Marie Pauline Rose - Baroness
# 472                               Appleyard, Ernest Silvanus.
# 480                                       BROOME, John Henry.
# 481                                       BROOME, John Henry.
# 519                                   ASHLEY, Florence Emily.
# 667                             ANDREWS, J. - Writer of Verse
# 874                                              ADAMS, Mary.
# 1143                                            OLDHAM, John.
# 1280        CARTE, Samuel.|JACKSON, Edward - Rector of Sou...
# 1808          AALL, J. C.|LANGE, Christian Christoph Andreas.
# 1905        S., L. G. D.|SIMONE, Luigi Giuseppe Oronzo Mar...
# 1929                                   WITKAMP, Pieter Harme.
# 2836                                      ASSERETO, Giovanni.
# 2854                                  READE, William Winwood.
# 2956                                         RADAU, Rodolphe.
# 2957                                         RADAU, Rodolphe.
# 3017                         ACOSTA Y CALBO, José Julian de.
# 3131                   ANDRÉ, John - Major|ARNOLD, Benedict.
# 4598                                       WRANGHAM, Francis.
# 4884                        BARHAM, Thomas Foster - the Elder
# 4976                   WHITE, Joseph - Canon of Christ Church
# 5382                                     LEECH, John - Artist
# 5385                                     LEECH, John - Artist
#
#             Corporate Author  Corporate Contributors Former owner  Engraver  \
# Identifier
# 206                      NaN                     NaN          NaN       NaN
# 216                      NaN                     NaN          NaN       NaN
# 218                      NaN                     NaN          NaN       NaN
# 472                      NaN                     NaN          NaN       NaN
# 480                      NaN                     NaN          NaN       NaN
# 481                      NaN                     NaN          NaN       NaN
# 519                      NaN                     NaN          NaN       NaN
# 667                      NaN                     NaN          NaN       NaN
# 874                      NaN                     NaN          NaN       NaN
# 1143                     NaN                     NaN          NaN       NaN
# 1280                     NaN                     NaN          NaN       NaN
# 1808                     NaN                     NaN          NaN       NaN
# 1905                     NaN                     NaN          NaN       NaN
# 1929                     NaN                     NaN          NaN       NaN
# 2836                     NaN                     NaN          NaN       NaN
# 2854                     NaN                     NaN          NaN       NaN
# 2956                     NaN                     NaN          NaN       NaN
# 2957                     NaN                     NaN          NaN       NaN
# 3017                     NaN                     NaN          NaN       NaN
# 3131                     NaN                     NaN          NaN       NaN
# 4598                     NaN                     NaN          NaN       NaN
# 4884                     NaN                     NaN          NaN       NaN
# 4976                     NaN                     NaN          NaN       NaN
# 5382                     NaN                     NaN          NaN       NaN
# 5385                     NaN                     NaN          NaN       NaN
#
#            Issuance type                                         Flickr URL  \
# Identifier
# 206          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 216          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 218          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 472          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 480          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 481          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 519          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 667          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 874          monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 1143         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 1280         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 1808         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 1905         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 1929         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 2836         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 2854         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 2956         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 2957         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 3017         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 3131         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 4598         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 4884         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 4976         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 5382         monographic  http://www.flickr.com/photos/britishlibrary/ta...
# 5385         monographic  http://www.flickr.com/photos/britishlibrary/ta...
#
#                                                    Shelfmarks
# Identifier
# 206                         British Library HMNTS 12641.b.30.
# 216                         British Library HMNTS 12626.cc.2.
# 218                         British Library HMNTS 12625.dd.1.
# 472                       British Library HMNTS 10369.bbb.15.
# 480                          British Library HMNTS 9007.d.28.
# 481                         British Library HMNTS 9006.ee.10.
# 519                          British Library HMNTS 12637.e.3.
# 667                        British Library HMNTS 011652.g.73.
# 874                        British Library HMNTS 11645.bb.42.
# 1143                   British Library HMNTS 11602.ee.10.(2.)
# 1280                         British Library HMNTS 1430.g.17.
# 1808                        British Library HMNTS 9425.cc.37.
# 1905                        British Library HMNTS 10136.g.22.
# 1929                     British Library HMNTS 10002.g.16-19.
# 2836                        British Library HMNTS 10136.h.24.
# 2854                      British Library HMNTS 12623.bbb.12.
# 2956                        British Library HMNTS 10096.i.19.
# 2957                        British Library HMNTS 10095.i.13.
# 3017                        British Library HMNTS 10480.h.18.
# 3131                         British Library HMNTS 9603.g.14.
# 4598                         British Library HMNTS 11641.f.1.
# 4884                       British Library HMNTS 994.l.1.(7.)
# 4976        British Library HMNTS 983.e.6.|British Library...
# 5382        British Library HMNTS C.131.d.16.|British Libr...
# 5385                          British Library HMNTS 9503.f.4.

# %%
df['Date of Publication'].head(25)
# Out:
# Identifier
# 206     1879
# 216      1868
# 218      1869
# 472      1851
# 480      1857
# 481      1875
# 519      1872
# 667       NaN
# 874      1676
# 1143     1679
# 1280     1802
# 1808     1859
# 1905     1888
# 1929     1839
# 2836     1897
# 2854     1865
# 2956     1860
# 2957     1873
# 3017     1866
# 3131     1899
# 4598     1814
# 4884     1820
# 4976     1800
# 5382     1847
# 5385      NaN
# Name: Date of Publication, dtype: object

# %%
def clean_title(title):
  if title=='nan':
    return 'NaN'
  if title[0]=='[':
    title=title[1:title.find(']')]
  if 'by' in title:
    title=title[:title.find('by')]
  elif 'By' in title:
    title=title[:title.find('By')]
  if '[' in title:
    title=title[:title.find('[')]

  title= title[:-2]

df['Title']=df['Title'].apply(clean_title)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher Title     Author  \
# Identifier
# 206              S. Tinsley & Co.  None      A. A.
# 216                  Virtue & Co.  None  A., A. A.
# 218         Bradbury, Evans & Co.  None  A., A. A.
# 472                 James Darling  None  A., E. S.
# 480          Wertheim & Macintosh  None  A., E. S.
#
#                                             Contributors  Corporate Author  \
# Identifier
# 206                                      FORBES, Walter.               NaN
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 218         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 472                          Appleyard, Ernest Silvanus.               NaN
# 480                                  BROOME, John Henry.               NaN
#
#             Corporate Contributors Former owner  Engraver Issuance type  \
# Identifier
# 206                            NaN          NaN       NaN   monographic
# 216                            NaN          NaN       NaN   monographic
# 218                            NaN          NaN       NaN   monographic
# 472                            NaN          NaN       NaN   monographic
# 480                            NaN          NaN       NaN   monographic
#
#                                                    Flickr URL  \
# Identifier
# 206         http://www.flickr.com/photos/britishlibrary/ta...
# 216         http://www.flickr.com/photos/britishlibrary/ta...
# 218         http://www.flickr.com/photos/britishlibrary/ta...
# 472         http://www.flickr.com/photos/britishlibrary/ta...
# 480         http://www.flickr.com/photos/britishlibrary/ta...
#
#                                      Shelfmarks
# Identifier
# 206           British Library HMNTS 12641.b.30.
# 216           British Library HMNTS 12626.cc.2.
# 218           British Library HMNTS 12625.dd.1.
# 472         British Library HMNTS 10369.bbb.15.
# 480            British Library HMNTS 9007.d.28.

# %%
df.loc[4159587]
# Out:
# Place of Publication                                    Newcastle upon Tyne
# Date of Publication                                                    1834
# Publisher                                                  Mackenzie & Dent
# Title                                                                  None
# Author                                                Mackenzie, E. (Eneas)
# Contributors                                           ROSS, M. - of Durham
# Corporate Author                                                        NaN
# Corporate Contributors                                                  NaN
# Former owner                                                            NaN
# Engraver                                                                NaN
# Issuance type                                                   monographic
# Flickr URL                http://www.flickr.com/photos/britishlibrary/ta...
# Shelfmarks                British Library HMNTS|British Library HMNTS 10...
# Name: 4159587, dtype: object

# %%
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London               1879
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                         Publisher Title     Author  \
# Identifier
# 206              S. Tinsley & Co.  None      A. A.
# 216                  Virtue & Co.  None  A., A. A.
# 218         Bradbury, Evans & Co.  None  A., A. A.
# 472                 James Darling  None  A., E. S.
# 480          Wertheim & Macintosh  None  A., E. S.
#
#                                             Contributors  Corporate Author  \
# Identifier
# 206                                      FORBES, Walter.               NaN
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 218         BLAZE DE BURY, Marie Pauline Rose - Baroness               NaN
# 472                          Appleyard, Ernest Silvanus.               NaN
# 480                                  BROOME, John Henry.               NaN
#
#             Corporate Contributors Former owner  Engraver Issuance type  \
# Identifier
# 206                            NaN          NaN       NaN   monographic
# 216                            NaN          NaN       NaN   monographic
# 218                            NaN          NaN       NaN   monographic
# 472                            NaN          NaN       NaN   monographic
# 480                            NaN          NaN       NaN   monographic
#
#                                                    Flickr URL  \
# Identifier
# 206         http://www.flickr.com/photos/britishlibrary/ta...
# 216         http://www.flickr.com/photos/britishlibrary/ta...
# 218         http://www.flickr.com/photos/britishlibrary/ta...
# 472         http://www.flickr.com/photos/britishlibrary/ta...
# 480         http://www.flickr.com/photos/britishlibrary/ta...
#
#                                      Shelfmarks
# Identifier
# 206           British Library HMNTS 12641.b.30.
# 216           British Library HMNTS 12626.cc.2.
# 218           British Library HMNTS 12625.dd.1.
# 472         British Library HMNTS 10369.bbb.15.
# 480            British Library HMNTS 9007.d.28.
